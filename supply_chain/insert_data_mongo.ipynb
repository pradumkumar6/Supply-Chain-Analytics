# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd

uri = "Your mongodb uri."

# Create a new client and connect to the server
client = MongoClient(uri)
db = client['inventory']
collection = db["supplychain_data"]

df=pd.read_csv("supply-chain-data.csv")

data_dict = df.to_dict(orient="records")
collection.insert_many(data_dict)
print("Successfully inserted the data.")
client.close()
# Out:
# Successfully inserted the data.

# %%
# %pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.11.3-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.11.3-cp312-cp312-win_amd64.whl (882 kB)
#    ---------------------------------------- 0.0/882.3 kB ? eta -:--:--
#    ----------------------- ---------------- 524.3/882.3 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 882.3/882.3 kB 2.3 MB/s eta 0:00:00
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.11.3
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 0         8661.996792            Non-binary            58           7
# 1         7460.900065                Female            53          30
# 2         9577.749626               Unknown             1          10
# 3         7766.836426            Non-binary            23          13
# 4         2686.505152            Non-binary             5           3
# ..                ...                   ...           ...         ...
# 95        7386.363944               Unknown            15          14
# 96        7698.424766            Non-binary            67           2
# 97        4370.916580                  Male            46          19
# 98        8525.952560                Female            53           1
# 99        9185.185829               Unknown            55           8
#
#     Order quantities  ...  Location Lead time  Production volumes  \
# 0                 96  ...    Mumbai        29                 215
# 1                 37  ...    Mumbai        23                 517
# 2                 88  ...    Mumbai        12                 971
# 3                 59  ...   Kolkata        24                 937
# 4                 56  ...     Delhi         5                 414
# ..               ...  ...       ...       ...                 ...
# 95                26  ...    Mumbai        18                 450
# 96                32  ...    Mumbai        28                 648
# 97                 4  ...    Mumbai        10                 535
# 98                27  ...   Chennai        28                 581
# 99                59  ...   Chennai        29                 921
#
#    Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                       29           46.279879             Pending
# 1                       30           33.616769             Pending
# 2                       27           30.688019             Pending
# 3                       18           35.624741                Fail
# 4                        3           92.065161                Fail
# ..                     ...                 ...                 ...
# 95                      26           58.890686             Pending
# 96                      28           17.803756             Pending
# 97                      13           65.765156                Fail
# 98                       9            5.604691             Pending
# 99                       2           38.072899                Fail
#
#     Defect rates  Transportation modes   Routes       Costs
# 0       0.226410                  Road  Route B  187.752075
# 1       4.854068                  Road  Route B  503.065579
# 2       4.580593                   Air  Route C  141.920282
# 3       4.746649                  Rail  Route A  254.776159
# 4       3.145580                   Air  Route A  923.440632
# ..           ...                   ...      ...         ...
# 95      1.210882                   Air  Route A  778.864241
# 96      3.872048                  Road  Route A  188.742141
# 97      3.376238                  Road  Route A  540.132423
# 98      2.908122                  Rail  Route A  882.198864
# 99      0.346027                  Rail  Route B  210.743009
#
# [100 rows x 24 columns]

# %%
df.to_dict(orient="records")
# Out:
# [{'Product type': 'haircare',
#   'SKU': 'SKU0',
#   'Price': 69.80800554211577,
#   'Availability': 55,
#   'Number of products sold': 802,
#   'Revenue generated': 8661.996792392383,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 58,
#   'Lead times': 7,
#   'Order quantities': 96,
#   'Shipping times': 4,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 2.956572139430807,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Mumbai',
#   'Lead time': 29,
#   'Production volumes': 215,
#   'Manufacturing lead time': 29,
#   'Manufacturing costs': 46.27987924050832,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.2264103608499251,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 187.75207545920392},
#  {'Product type': 'skincare',
#   'SKU': 'SKU1',
#   'Price': 14.84352327508434,
#   'Availability': 95,
#   'Number of products sold': 736,
#   'Revenue generated': 7460.900065445849,
#   'Customer demographics': 'Female',
#   'Stock levels': 53,
#   'Lead times': 30,
#   'Order quantities': 37,
#   'Shipping times': 2,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 9.71657477143131,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Mumbai',
#   'Lead time': 23,
#   'Production volumes': 517,
#   'Manufacturing lead time': 30,
#   'Manufacturing costs': 33.61676895373,
#   'Inspection results': 'Pending',
#   'Defect rates': 4.854068026388706,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 503.0655791496692},
#  {'Product type': 'haircare',
#   'SKU': 'SKU2',
#   'Price': 11.319683293090566,
#   'Availability': 34,
#   'Number of products sold': 8,
#   'Revenue generated': 9577.74962586873,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 1,
#   'Lead times': 10,
#   'Order quantities': 88,
#   'Shipping times': 2,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 8.054479261732155,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Mumbai',
#   'Lead time': 12,
#   'Production volumes': 971,
#   'Manufacturing lead time': 27,
#   'Manufacturing costs': 30.688019348284204,
#   'Inspection results': 'Pending',
#   'Defect rates': 4.580592619199229,
#   'Transportation modes': 'Air',
#   'Routes': 'Route C',
#   'Costs': 141.92028177151906},
#  {'Product type': 'skincare',
#   'SKU': 'SKU3',
#   'Price': 61.163343016437736,
#   'Availability': 68,
#   'Number of products sold': 83,
#   'Revenue generated': 7766.836425685233,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 23,
#   'Lead times': 13,
#   'Order quantities': 59,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 1.7295685635434288,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Kolkata',
#   'Lead time': 24,
#   'Production volumes': 937,
#   'Manufacturing lead time': 18,
#   'Manufacturing costs': 35.62474139712503,
#   'Inspection results': 'Fail',
#   'Defect rates': 4.74664862064775,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 254.77615921928663},
#  {'Product type': 'skincare',
#   'SKU': 'SKU4',
#   'Price': 4.805496036345893,
#   'Availability': 26,
#   'Number of products sold': 871,
#   'Revenue generated': 2686.505151567447,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 5,
#   'Lead times': 3,
#   'Order quantities': 56,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 3.890547915870672,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Delhi',
#   'Lead time': 5,
#   'Production volumes': 414,
#   'Manufacturing lead time': 3,
#   'Manufacturing costs': 92.06516059871284,
#   'Inspection results': 'Fail',
#   'Defect rates': 3.145579522833002,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 923.4406317119222},
#  {'Product type': 'haircare',
#   'SKU': 'SKU5',
#   'Price': 1.6999760138659377,
#   'Availability': 87,
#   'Number of products sold': 147,
#   'Revenue generated': 2828.348745975759,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 90,
#   'Lead times': 27,
#   'Order quantities': 66,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 4.444098864382293,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Bangalore',
#   'Lead time': 10,
#   'Production volumes': 104,
#   'Manufacturing lead time': 17,
#   'Manufacturing costs': 56.7664755574318,
#   'Inspection results': 'Fail',
#   'Defect rates': 2.7791935115711617,
#   'Transportation modes': 'Road',
#   'Routes': 'Route A',
#   'Costs': 235.4612367355375},
#  {'Product type': 'skincare',
#   'SKU': 'SKU6',
#   'Price': 4.078332863107945,
#   'Availability': 48,
#   'Number of products sold': 65,
#   'Revenue generated': 7823.476559531737,
#   'Customer demographics': 'Male',
#   'Stock levels': 11,
#   'Lead times': 15,
#   'Order quantities': 58,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 3.880763302952003,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Kolkata',
#   'Lead time': 14,
#   'Production volumes': 314,
#   'Manufacturing lead time': 24,
#   'Manufacturing costs': 1.0850685695870688,
#   'Inspection results': 'Pending',
#   'Defect rates': 1.0009106193041355,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route A',
#   'Costs': 134.36909686103172},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU7',
#   'Price': 42.95838438246007,
#   'Availability': 59,
#   'Number of products sold': 426,
#   'Revenue generated': 8496.103813089838,
#   'Customer demographics': 'Female',
#   'Stock levels': 93,
#   'Lead times': 17,
#   'Order quantities': 11,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 2.3483387844177805,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Bangalore',
#   'Lead time': 22,
#   'Production volumes': 564,
#   'Manufacturing lead time': 1,
#   'Manufacturing costs': 99.46610860359912,
#   'Inspection results': 'Fail',
#   'Defect rates': 0.3981771868506506,
#   'Transportation modes': 'Road',
#   'Routes': 'Route C',
#   'Costs': 802.0563118175586},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU8',
#   'Price': 68.71759674852733,
#   'Availability': 78,
#   'Number of products sold': 150,
#   'Revenue generated': 7517.363210631127,
#   'Customer demographics': 'Female',
#   'Stock levels': 5,
#   'Lead times': 10,
#   'Order quantities': 15,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 3.4047338570830266,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Mumbai',
#   'Lead time': 13,
#   'Production volumes': 769,
#   'Manufacturing lead time': 8,
#   'Manufacturing costs': 11.423027139565695,
#   'Inspection results': 'Pending',
#   'Defect rates': 2.709862691109961,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route B',
#   'Costs': 505.55713422546415},
#  {'Product type': 'skincare',
#   'SKU': 'SKU9',
#   'Price': 64.01573294127854,
#   'Availability': 35,
#   'Number of products sold': 980,
#   'Revenue generated': 4971.145987585558,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 14,
#   'Lead times': 27,
#   'Order quantities': 83,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 7.166645291048216,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Chennai',
#   'Lead time': 29,
#   'Production volumes': 963,
#   'Manufacturing lead time': 23,
#   'Manufacturing costs': 47.95760163495158,
#   'Inspection results': 'Pending',
#   'Defect rates': 3.844614478767585,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 995.9294614986416},
#  {'Product type': 'skincare',
#   'SKU': 'SKU10',
#   'Price': 15.707795681912138,
#   'Availability': 11,
#   'Number of products sold': 996,
#   'Revenue generated': 2330.965802091949,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 51,
#   'Lead times': 13,
#   'Order quantities': 80,
#   'Shipping times': 2,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 8.673211211278613,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Kolkata',
#   'Lead time': 18,
#   'Production volumes': 830,
#   'Manufacturing lead time': 5,
#   'Manufacturing costs': 96.52735278531092,
#   'Inspection results': 'Pass',
#   'Defect rates': 1.7273139283559424,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 806.103177702923},
#  {'Product type': 'skincare',
#   'SKU': 'SKU11',
#   'Price': 90.63545998228868,
#   'Availability': 95,
#   'Number of products sold': 960,
#   'Revenue generated': 6099.944115581452,
#   'Customer demographics': 'Female',
#   'Stock levels': 46,
#   'Lead times': 23,
#   'Order quantities': 60,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 4.523943124316663,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Kolkata',
#   'Lead time': 28,
#   'Production volumes': 362,
#   'Manufacturing lead time': 11,
#   'Manufacturing costs': 27.592363086663696,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.0211698213729943,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 126.72303340940724},
#  {'Product type': 'haircare',
#   'SKU': 'SKU12',
#   'Price': 71.21338907536008,
#   'Availability': 41,
#   'Number of products sold': 336,
#   'Revenue generated': 2873.7414460214413,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 100,
#   'Lead times': 30,
#   'Order quantities': 85,
#   'Shipping times': 4,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 1.325274010184522,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Kolkata',
#   'Lead time': 3,
#   'Production volumes': 563,
#   'Manufacturing lead time': 3,
#   'Manufacturing costs': 32.32128621342403,
#   'Inspection results': 'Fail',
#   'Defect rates': 2.161253747555912,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 402.9687890737706},
#  {'Product type': 'skincare',
#   'SKU': 'SKU13',
#   'Price': 16.160393317379977,
#   'Availability': 5,
#   'Number of products sold': 249,
#   'Revenue generated': 4052.738416237866,
#   'Customer demographics': 'Male',
#   'Stock levels': 80,
#   'Lead times': 8,
#   'Order quantities': 48,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 9.537283061108338,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Bangalore',
#   'Lead time': 23,
#   'Production volumes': 173,
#   'Manufacturing lead time': 10,
#   'Manufacturing costs': 97.82905011017328,
#   'Inspection results': 'Pending',
#   'Defect rates': 1.6310742300715386,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 547.2410051609685},
#  {'Product type': 'skincare',
#   'SKU': 'SKU14',
#   'Price': 99.1713286386242,
#   'Availability': 26,
#   'Number of products sold': 562,
#   'Revenue generated': 8653.570926469802,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 54,
#   'Lead times': 29,
#   'Order quantities': 78,
#   'Shipping times': 5,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 2.039770189449332,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Kolkata',
#   'Lead time': 25,
#   'Production volumes': 558,
#   'Manufacturing lead time': 14,
#   'Manufacturing costs': 5.791436629862989,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.1006828515650937,
#   'Transportation modes': 'Air',
#   'Routes': 'Route B',
#   'Costs': 929.2352899608896},
#  {'Product type': 'skincare',
#   'SKU': 'SKU15',
#   'Price': 36.98924492862691,
#   'Availability': 94,
#   'Number of products sold': 469,
#   'Revenue generated': 5442.086785397673,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 9,
#   'Lead times': 8,
#   'Order quantities': 69,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 2.4220397232752044,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Bangalore',
#   'Lead time': 14,
#   'Production volumes': 580,
#   'Manufacturing lead time': 7,
#   'Manufacturing costs': 97.12128175147431,
#   'Inspection results': 'Pass',
#   'Defect rates': 2.264405761198549,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route B',
#   'Costs': 127.8618000016254},
#  {'Product type': 'skincare',
#   'SKU': 'SKU16',
#   'Price': 7.547172109791272,
#   'Availability': 74,
#   'Number of products sold': 280,
#   'Revenue generated': 6453.797968176285,
#   'Customer demographics': 'Female',
#   'Stock levels': 2,
#   'Lead times': 5,
#   'Order quantities': 78,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 4.191324585705502,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Bangalore',
#   'Lead time': 3,
#   'Production volumes': 399,
#   'Manufacturing lead time': 21,
#   'Manufacturing costs': 77.10634249785001,
#   'Inspection results': 'Pass',
#   'Defect rates': 1.012563089258049,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 865.5257797712403},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU17',
#   'Price': 81.46253436923702,
#   'Availability': 82,
#   'Number of products sold': 126,
#   'Revenue generated': 2629.396434845262,
#   'Customer demographics': 'Female',
#   'Stock levels': 45,
#   'Lead times': 17,
#   'Order quantities': 85,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 3.585418958232342,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Chennai',
#   'Lead time': 7,
#   'Production volumes': 453,
#   'Manufacturing lead time': 16,
#   'Manufacturing costs': 47.679680368355335,
#   'Inspection results': 'Fail',
#   'Defect rates': 0.1020207549181761,
#   'Transportation modes': 'Air',
#   'Routes': 'Route C',
#   'Costs': 670.9343907924103},
#  {'Product type': 'haircare',
#   'SKU': 'SKU18',
#   'Price': 36.443627770460935,
#   'Availability': 23,
#   'Number of products sold': 620,
#   'Revenue generated': 9364.673505076173,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 10,
#   'Lead times': 10,
#   'Order quantities': 46,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 4.339224714110709,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Kolkata',
#   'Lead time': 18,
#   'Production volumes': 374,
#   'Manufacturing lead time': 17,
#   'Manufacturing costs': 27.10798085484392,
#   'Inspection results': 'Pending',
#   'Defect rates': 2.231939110729264,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route A',
#   'Costs': 593.4802587206518},
#  {'Product type': 'skincare',
#   'SKU': 'SKU19',
#   'Price': 51.12387008796474,
#   'Availability': 100,
#   'Number of products sold': 187,
#   'Revenue generated': 2553.495584991215,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 48,
#   'Lead times': 11,
#   'Order quantities': 94,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 4.742635882841877,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Chennai',
#   'Lead time': 20,
#   'Production volumes': 694,
#   'Manufacturing lead time': 16,
#   'Manufacturing costs': 82.37332058799021,
#   'Inspection results': 'Fail',
#   'Defect rates': 3.646450865417029,
#   'Transportation modes': 'Road',
#   'Routes': 'Route C',
#   'Costs': 477.3076310909034},
#  {'Product type': 'skincare',
#   'SKU': 'SKU20',
#   'Price': 96.34107243996338,
#   'Availability': 22,
#   'Number of products sold': 320,
#   'Revenue generated': 8128.027696851192,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 27,
#   'Lead times': 12,
#   'Order quantities': 68,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 8.87833465092684,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Chennai',
#   'Lead time': 29,
#   'Production volumes': 309,
#   'Manufacturing lead time': 6,
#   'Manufacturing costs': 65.68625960848863,
#   'Inspection results': 'Pass',
#   'Defect rates': 4.231416573534539,
#   'Transportation modes': 'Air',
#   'Routes': 'Route B',
#   'Costs': 493.87121531620585},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU21',
#   'Price': 84.89386898495083,
#   'Availability': 60,
#   'Number of products sold': 601,
#   'Revenue generated': 7087.052696357437,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 69,
#   'Lead times': 25,
#   'Order quantities': 7,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 6.037883769218298,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Chennai',
#   'Lead time': 19,
#   'Production volumes': 791,
#   'Manufacturing lead time': 4,
#   'Manufacturing costs': 61.73572895416093,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.0186075676310149,
#   'Transportation modes': 'Air',
#   'Routes': 'Route C',
#   'Costs': 523.360914720158},
#  {'Product type': 'haircare',
#   'SKU': 'SKU22',
#   'Price': 27.67978088650196,
#   'Availability': 55,
#   'Number of products sold': 884,
#   'Revenue generated': 2390.8078665561734,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 71,
#   'Lead times': 1,
#   'Order quantities': 63,
#   'Shipping times': 10,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 9.56764892092304,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Kolkata',
#   'Lead time': 22,
#   'Production volumes': 780,
#   'Manufacturing lead time': 28,
#   'Manufacturing costs': 50.12083961297735,
#   'Inspection results': 'Fail',
#   'Defect rates': 2.591275473211116,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route C',
#   'Costs': 205.57199582694707},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU23',
#   'Price': 4.324341185864164,
#   'Availability': 30,
#   'Number of products sold': 391,
#   'Revenue generated': 8858.367571011484,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 84,
#   'Lead times': 5,
#   'Order quantities': 29,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 2.924857601145554,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Kolkata',
#   'Lead time': 11,
#   'Production volumes': 568,
#   'Manufacturing lead time': 29,
#   'Manufacturing costs': 98.60995724270389,
#   'Inspection results': 'Pending',
#   'Defect rates': 1.342291562722734,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 196.32944611241268},
#  {'Product type': 'haircare',
#   'SKU': 'SKU24',
#   'Price': 4.156308359311108,
#   'Availability': 32,
#   'Number of products sold': 209,
#   'Revenue generated': 9049.077860939897,
#   'Customer demographics': 'Male',
#   'Stock levels': 4,
#   'Lead times': 26,
#   'Order quantities': 2,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 9.741291689284369,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Bangalore',
#   'Lead time': 28,
#   'Production volumes': 447,
#   'Manufacturing lead time': 3,
#   'Manufacturing costs': 40.382359702924816,
#   'Inspection results': 'Pending',
#   'Defect rates': 3.691310292628728,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 758.7247726029383},
#  {'Product type': 'haircare',
#   'SKU': 'SKU25',
#   'Price': 39.62934398509263,
#   'Availability': 73,
#   'Number of products sold': 142,
#   'Revenue generated': 2174.777054350654,
#   'Customer demographics': 'Male',
#   'Stock levels': 82,
#   'Lead times': 11,
#   'Order quantities': 52,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 2.231073681281728,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Kolkata',
#   'Lead time': 19,
#   'Production volumes': 934,
#   'Manufacturing lead time': 23,
#   'Manufacturing costs': 78.28038311841539,
#   'Inspection results': 'Pending',
#   'Defect rates': 3.797231217114183,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 458.535945739209},
#  {'Product type': 'haircare',
#   'SKU': 'SKU26',
#   'Price': 97.44694661789282,
#   'Availability': 9,
#   'Number of products sold': 353,
#   'Revenue generated': 3716.493325894037,
#   'Customer demographics': 'Male',
#   'Stock levels': 59,
#   'Lead times': 16,
#   'Order quantities': 48,
#   'Shipping times': 4,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 6.507548621078551,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Bangalore',
#   'Lead time': 26,
#   'Production volumes': 171,
#   'Manufacturing lead time': 4,
#   'Manufacturing costs': 15.97222975718176,
#   'Inspection results': 'Pass',
#   'Defect rates': 2.119319736724923,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 617.8669164583772},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU27',
#   'Price': 92.55736081240202,
#   'Availability': 42,
#   'Number of products sold': 352,
#   'Revenue generated': 2686.457223575984,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 47,
#   'Lead times': 9,
#   'Order quantities': 62,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 7.406750952998074,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Mumbai',
#   'Lead time': 25,
#   'Production volumes': 291,
#   'Manufacturing lead time': 4,
#   'Manufacturing costs': 10.528245070042162,
#   'Inspection results': 'Fail',
#   'Defect rates': 2.864667837883373,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route B',
#   'Costs': 762.4591821556837},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU28',
#   'Price': 2.397274705597141,
#   'Availability': 12,
#   'Number of products sold': 394,
#   'Revenue generated': 6117.324615083992,
#   'Customer demographics': 'Female',
#   'Stock levels': 48,
#   'Lead times': 15,
#   'Order quantities': 24,
#   'Shipping times': 4,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 9.898140508069222,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Mumbai',
#   'Lead time': 13,
#   'Production volumes': 171,
#   'Manufacturing lead time': 7,
#   'Manufacturing costs': 59.42938181069157,
#   'Inspection results': 'Fail',
#   'Defect rates': 0.815757079295672,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 123.43702751182708},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU29',
#   'Price': 63.44755918520733,
#   'Availability': 3,
#   'Number of products sold': 253,
#   'Revenue generated': 8318.903194617178,
#   'Customer demographics': 'Female',
#   'Stock levels': 45,
#   'Lead times': 5,
#   'Order quantities': 67,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 8.100973145397031,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Kolkata',
#   'Lead time': 16,
#   'Production volumes': 329,
#   'Manufacturing lead time': 7,
#   'Manufacturing costs': 39.29287558606575,
#   'Inspection results': 'Pass',
#   'Defect rates': 3.878098936588488,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 764.9353759407081},
#  {'Product type': 'haircare',
#   'SKU': 'SKU30',
#   'Price': 8.022859210526393,
#   'Availability': 10,
#   'Number of products sold': 327,
#   'Revenue generated': 2766.342366866089,
#   'Customer demographics': 'Male',
#   'Stock levels': 60,
#   'Lead times': 26,
#   'Order quantities': 35,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 8.954528315318015,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Kolkata',
#   'Lead time': 27,
#   'Production volumes': 806,
#   'Manufacturing lead time': 30,
#   'Manufacturing costs': 51.63489340010933,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.9653947053523932,
#   'Transportation modes': 'Road',
#   'Routes': 'Route C',
#   'Costs': 880.080988247161},
#  {'Product type': 'skincare',
#   'SKU': 'SKU31',
#   'Price': 50.8473930517187,
#   'Availability': 28,
#   'Number of products sold': 168,
#   'Revenue generated': 9655.135102719398,
#   'Customer demographics': 'Male',
#   'Stock levels': 6,
#   'Lead times': 17,
#   'Order quantities': 44,
#   'Shipping times': 4,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 2.6796609649814065,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Chennai',
#   'Lead time': 24,
#   'Production volumes': 461,
#   'Manufacturing lead time': 8,
#   'Manufacturing costs': 60.25114566159808,
#   'Inspection results': 'Pending',
#   'Defect rates': 2.9890000066550746,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route C',
#   'Costs': 609.3792066184267},
#  {'Product type': 'skincare',
#   'SKU': 'SKU32',
#   'Price': 79.20993601565672,
#   'Availability': 43,
#   'Number of products sold': 781,
#   'Revenue generated': 9571.55048732782,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 89,
#   'Lead times': 13,
#   'Order quantities': 64,
#   'Shipping times': 4,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 6.599104901238584,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Kolkata',
#   'Lead time': 30,
#   'Production volumes': 737,
#   'Manufacturing lead time': 7,
#   'Manufacturing costs': 29.69246715374977,
#   'Inspection results': 'Pass',
#   'Defect rates': 1.946036119386113,
#   'Transportation modes': 'Road',
#   'Routes': 'Route A',
#   'Costs': 761.1739095148776},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU33',
#   'Price': 64.7954350001556,
#   'Availability': 63,
#   'Number of products sold': 616,
#   'Revenue generated': 5149.9983504080365,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 4,
#   'Lead times': 17,
#   'Order quantities': 95,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 4.85827050343664,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Chennai',
#   'Lead time': 1,
#   'Production volumes': 251,
#   'Manufacturing lead time': 23,
#   'Manufacturing costs': 23.853427512896133,
#   'Inspection results': 'Fail',
#   'Defect rates': 3.541046012250923,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route A',
#   'Costs': 371.255295519871},
#  {'Product type': 'skincare',
#   'SKU': 'SKU34',
#   'Price': 37.46759232984246,
#   'Availability': 96,
#   'Number of products sold': 602,
#   'Revenue generated': 9061.710895507724,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 1,
#   'Lead times': 26,
#   'Order quantities': 21,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 1.019487570822119,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Chennai',
#   'Lead time': 4,
#   'Production volumes': 452,
#   'Manufacturing lead time': 10,
#   'Manufacturing costs': 10.754272815029331,
#   'Inspection results': 'Pass',
#   'Defect rates': 0.6466045593720549,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 510.3580004335235},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU35',
#   'Price': 84.95778681635043,
#   'Availability': 11,
#   'Number of products sold': 449,
#   'Revenue generated': 6541.329344802465,
#   'Customer demographics': 'Female',
#   'Stock levels': 42,
#   'Lead times': 27,
#   'Order quantities': 85,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 5.288189990327409,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Delhi',
#   'Lead time': 3,
#   'Production volumes': 367,
#   'Manufacturing lead time': 2,
#   'Manufacturing costs': 58.004787044743765,
#   'Inspection results': 'Pass',
#   'Defect rates': 0.5411540980605811,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route C',
#   'Costs': 553.4204712303558},
#  {'Product type': 'skincare',
#   'SKU': 'SKU36',
#   'Price': 9.813002578754052,
#   'Availability': 34,
#   'Number of products sold': 963,
#   'Revenue generated': 7573.402457848733,
#   'Customer demographics': 'Female',
#   'Stock levels': 18,
#   'Lead times': 23,
#   'Order quantities': 28,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 2.107951267159081,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Delhi',
#   'Lead time': 26,
#   'Production volumes': 671,
#   'Manufacturing lead time': 19,
#   'Manufacturing costs': 45.531364237162144,
#   'Inspection results': 'Fail',
#   'Defect rates': 3.8055333792433537,
#   'Transportation modes': 'Air',
#   'Routes': 'Route C',
#   'Costs': 403.8089742481805},
#  {'Product type': 'skincare',
#   'SKU': 'SKU37',
#   'Price': 23.39984475261435,
#   'Availability': 5,
#   'Number of products sold': 963,
#   'Revenue generated': 2438.339930470029,
#   'Customer demographics': 'Female',
#   'Stock levels': 25,
#   'Lead times': 8,
#   'Order quantities': 21,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 1.5326552735904306,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Kolkata',
#   'Lead time': 24,
#   'Production volumes': 867,
#   'Manufacturing lead time': 15,
#   'Manufacturing costs': 34.34327746507538,
#   'Inspection results': 'Pending',
#   'Defect rates': 2.610288084848113,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route A',
#   'Costs': 183.9329680435944},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU38',
#   'Price': 52.0759306827078,
#   'Availability': 75,
#   'Number of products sold': 705,
#   'Revenue generated': 9692.318040218432,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 69,
#   'Lead times': 1,
#   'Order quantities': 88,
#   'Shipping times': 5,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 9.235931437249228,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Mumbai',
#   'Lead time': 10,
#   'Production volumes': 841,
#   'Manufacturing lead time': 12,
#   'Manufacturing costs': 5.930693645528318,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.6133268991645074,
#   'Transportation modes': 'Air',
#   'Routes': 'Route B',
#   'Costs': 339.6728699486061},
#  {'Product type': 'skincare',
#   'SKU': 'SKU39',
#   'Price': 19.127477265823256,
#   'Availability': 26,
#   'Number of products sold': 176,
#   'Revenue generated': 1912.4656631007608,
#   'Customer demographics': 'Female',
#   'Stock levels': 78,
#   'Lead times': 29,
#   'Order quantities': 34,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 5.562503778830384,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Kolkata',
#   'Lead time': 30,
#   'Production volumes': 791,
#   'Manufacturing lead time': 6,
#   'Manufacturing costs': 9.005807428781642,
#   'Inspection results': 'Fail',
#   'Defect rates': 1.451972203996816,
#   'Transportation modes': 'Air',
#   'Routes': 'Route B',
#   'Costs': 653.6729945520332},
#  {'Product type': 'skincare',
#   'SKU': 'SKU40',
#   'Price': 80.54142417094033,
#   'Availability': 97,
#   'Number of products sold': 933,
#   'Revenue generated': 5724.959350456265,
#   'Customer demographics': 'Female',
#   'Stock levels': 90,
#   'Lead times': 20,
#   'Order quantities': 39,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 7.229595139736474,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Kolkata',
#   'Lead time': 18,
#   'Production volumes': 793,
#   'Manufacturing lead time': 1,
#   'Manufacturing costs': 88.17940710421746,
#   'Inspection results': 'Pending',
#   'Defect rates': 4.213269430586566,
#   'Transportation modes': 'Road',
#   'Routes': 'Route A',
#   'Costs': 529.8087239806919},
#  {'Product type': 'skincare',
#   'SKU': 'SKU41',
#   'Price': 99.11329161531717,
#   'Availability': 35,
#   'Number of products sold': 556,
#   'Revenue generated': 5521.205259010972,
#   'Customer demographics': 'Female',
#   'Stock levels': 64,
#   'Lead times': 19,
#   'Order quantities': 38,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 5.773263743766654,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Chennai',
#   'Lead time': 18,
#   'Production volumes': 892,
#   'Manufacturing lead time': 7,
#   'Manufacturing costs': 95.3320645487725,
#   'Inspection results': 'Fail',
#   'Defect rates': 0.0453022623982596,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route A',
#   'Costs': 275.5243711313098},
#  {'Product type': 'skincare',
#   'SKU': 'SKU42',
#   'Price': 46.52916761451677,
#   'Availability': 98,
#   'Number of products sold': 155,
#   'Revenue generated': 1839.609425856764,
#   'Customer demographics': 'Female',
#   'Stock levels': 22,
#   'Lead times': 27,
#   'Order quantities': 57,
#   'Shipping times': 4,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 7.526248326851508,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Bangalore',
#   'Lead time': 26,
#   'Production volumes': 179,
#   'Manufacturing lead time': 7,
#   'Manufacturing costs': 96.42282063957188,
#   'Inspection results': 'Fail',
#   'Defect rates': 4.939255288620948,
#   'Transportation modes': 'Road',
#   'Routes': 'Route A',
#   'Costs': 635.6571205019919},
#  {'Product type': 'haircare',
#   'SKU': 'SKU43',
#   'Price': 11.74327177630924,
#   'Availability': 6,
#   'Number of products sold': 598,
#   'Revenue generated': 5737.425599119023,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 36,
#   'Lead times': 29,
#   'Order quantities': 85,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 3.6940212683884543,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Mumbai',
#   'Lead time': 1,
#   'Production volumes': 206,
#   'Manufacturing lead time': 23,
#   'Manufacturing costs': 26.27736595733241,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.3723047679850977,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 716.0441197593407},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU44',
#   'Price': 51.35579091311039,
#   'Availability': 34,
#   'Number of products sold': 919,
#   'Revenue generated': 7152.2860494355145,
#   'Customer demographics': 'Female',
#   'Stock levels': 13,
#   'Lead times': 19,
#   'Order quantities': 72,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 7.577449657376693,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Delhi',
#   'Lead time': 7,
#   'Production volumes': 834,
#   'Manufacturing lead time': 18,
#   'Manufacturing costs': 22.554106620887744,
#   'Inspection results': 'Fail',
#   'Defect rates': 2.962626320454882,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 610.4532696192277},
#  {'Product type': 'haircare',
#   'SKU': 'SKU45',
#   'Price': 33.78413803306551,
#   'Availability': 1,
#   'Number of products sold': 24,
#   'Revenue generated': 5267.956807510521,
#   'Customer demographics': 'Male',
#   'Stock levels': 93,
#   'Lead times': 7,
#   'Order quantities': 52,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 5.21515500871191,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Chennai',
#   'Lead time': 25,
#   'Production volumes': 794,
#   'Manufacturing lead time': 25,
#   'Manufacturing costs': 66.31254443999165,
#   'Inspection results': 'Pass',
#   'Defect rates': 3.219604612084106,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 495.305697028474},
#  {'Product type': 'haircare',
#   'SKU': 'SKU46',
#   'Price': 27.0822071998889,
#   'Availability': 75,
#   'Number of products sold': 859,
#   'Revenue generated': 2556.767360633596,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 92,
#   'Lead times': 29,
#   'Order quantities': 6,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 4.070955837084083,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Chennai',
#   'Lead time': 18,
#   'Production volumes': 870,
#   'Manufacturing lead time': 23,
#   'Manufacturing costs': 77.32235321105162,
#   'Inspection results': 'Pending',
#   'Defect rates': 3.6486105925362033,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 380.4359371119643},
#  {'Product type': 'skincare',
#   'SKU': 'SKU47',
#   'Price': 95.71213588093607,
#   'Availability': 93,
#   'Number of products sold': 910,
#   'Revenue generated': 7089.474249934186,
#   'Customer demographics': 'Male',
#   'Stock levels': 4,
#   'Lead times': 15,
#   'Order quantities': 51,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 8.97875075594997,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Kolkata',
#   'Lead time': 10,
#   'Production volumes': 964,
#   'Manufacturing lead time': 20,
#   'Manufacturing costs': 19.712992911293647,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.3805735867132137,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 581.6023550505868},
#  {'Product type': 'haircare',
#   'SKU': 'SKU48',
#   'Price': 76.03554442689172,
#   'Availability': 28,
#   'Number of products sold': 29,
#   'Revenue generated': 7397.07100458718,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 30,
#   'Lead times': 16,
#   'Order quantities': 9,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 7.0958331565551385,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Mumbai',
#   'Lead time': 9,
#   'Production volumes': 109,
#   'Manufacturing lead time': 18,
#   'Manufacturing costs': 23.126363582464776,
#   'Inspection results': 'Fail',
#   'Defect rates': 1.6981125407144038,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 768.65191395437},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU49',
#   'Price': 78.89791320564004,
#   'Availability': 19,
#   'Number of products sold': 99,
#   'Revenue generated': 8001.613206519002,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 97,
#   'Lead times': 24,
#   'Order quantities': 9,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 2.5056210329009154,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Delhi',
#   'Lead time': 28,
#   'Production volumes': 177,
#   'Manufacturing lead time': 28,
#   'Manufacturing costs': 14.147815443979216,
#   'Inspection results': 'Pass',
#   'Defect rates': 2.825813985400132,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 336.8901685199779},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU50',
#   'Price': 14.203484264803022,
#   'Availability': 91,
#   'Number of products sold': 633,
#   'Revenue generated': 5910.885389668899,
#   'Customer demographics': 'Female',
#   'Stock levels': 31,
#   'Lead times': 23,
#   'Order quantities': 82,
#   'Shipping times': 10,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 6.247860914975991,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Delhi',
#   'Lead time': 20,
#   'Production volumes': 306,
#   'Manufacturing lead time': 21,
#   'Manufacturing costs': 45.17875792463452,
#   'Inspection results': 'Fail',
#   'Defect rates': 4.754800804671185,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 496.24865029194046},
#  {'Product type': 'haircare',
#   'SKU': 'SKU51',
#   'Price': 26.70076097246173,
#   'Availability': 61,
#   'Number of products sold': 154,
#   'Revenue generated': 9866.465457979695,
#   'Customer demographics': 'Male',
#   'Stock levels': 100,
#   'Lead times': 4,
#   'Order quantities': 52,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 4.783000557947665,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Bangalore',
#   'Lead time': 18,
#   'Production volumes': 673,
#   'Manufacturing lead time': 28,
#   'Manufacturing costs': 14.19032834456998,
#   'Inspection results': 'Pending',
#   'Defect rates': 1.7729511720835571,
#   'Transportation modes': 'Road',
#   'Routes': 'Route A',
#   'Costs': 694.9823175794459},
#  {'Product type': 'skincare',
#   'SKU': 'SKU52',
#   'Price': 98.03182965646508,
#   'Availability': 1,
#   'Number of products sold': 820,
#   'Revenue generated': 9435.76260891213,
#   'Customer demographics': 'Male',
#   'Stock levels': 64,
#   'Lead times': 11,
#   'Order quantities': 11,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 8.631052179768947,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Mumbai',
#   'Lead time': 10,
#   'Production volumes': 727,
#   'Manufacturing lead time': 27,
#   'Manufacturing costs': 9.166849148597151,
#   'Inspection results': 'Pending',
#   'Defect rates': 2.1224716191438247,
#   'Transportation modes': 'Air',
#   'Routes': 'Route C',
#   'Costs': 602.8984988383834},
#  {'Product type': 'skincare',
#   'SKU': 'SKU53',
#   'Price': 30.34147071121421,
#   'Availability': 93,
#   'Number of products sold': 242,
#   'Revenue generated': 8232.334829425821,
#   'Customer demographics': 'Male',
#   'Stock levels': 96,
#   'Lead times': 25,
#   'Order quantities': 54,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 1.0134865660958965,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Delhi',
#   'Lead time': 1,
#   'Production volumes': 631,
#   'Manufacturing lead time': 17,
#   'Manufacturing costs': 83.34405899167797,
#   'Inspection results': 'Pending',
#   'Defect rates': 1.4103475760760271,
#   'Transportation modes': 'Air',
#   'Routes': 'Route B',
#   'Costs': 750.7378406682709},
#  {'Product type': 'haircare',
#   'SKU': 'SKU54',
#   'Price': 31.146243160240854,
#   'Availability': 11,
#   'Number of products sold': 622,
#   'Revenue generated': 6088.021479940859,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 33,
#   'Lead times': 22,
#   'Order quantities': 61,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 4.305103471287636,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Kolkata',
#   'Lead time': 26,
#   'Production volumes': 497,
#   'Manufacturing lead time': 29,
#   'Manufacturing costs': 30.186023375822508,
#   'Inspection results': 'Pass',
#   'Defect rates': 2.478771975539748,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 814.0699965821875},
#  {'Product type': 'haircare',
#   'SKU': 'SKU55',
#   'Price': 79.85505834078943,
#   'Availability': 16,
#   'Number of products sold': 701,
#   'Revenue generated': 2925.6751703038126,
#   'Customer demographics': 'Male',
#   'Stock levels': 97,
#   'Lead times': 11,
#   'Order quantities': 11,
#   'Shipping times': 5,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 5.014364955030907,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Delhi',
#   'Lead time': 27,
#   'Production volumes': 918,
#   'Manufacturing lead time': 5,
#   'Manufacturing costs': 30.3235452566165,
#   'Inspection results': 'Fail',
#   'Defect rates': 4.548919659396385,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route B',
#   'Costs': 323.01292795247883},
#  {'Product type': 'skincare',
#   'SKU': 'SKU56',
#   'Price': 20.986386037043378,
#   'Availability': 90,
#   'Number of products sold': 93,
#   'Revenue generated': 4767.020484344137,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 25,
#   'Lead times': 23,
#   'Order quantities': 83,
#   'Shipping times': 5,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 1.7744297140717396,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Mumbai',
#   'Lead time': 24,
#   'Production volumes': 826,
#   'Manufacturing lead time': 28,
#   'Manufacturing costs': 12.836284572832753,
#   'Inspection results': 'Pass',
#   'Defect rates': 1.173755495387454,
#   'Transportation modes': 'Air',
#   'Routes': 'Route B',
#   'Costs': 832.2108087060217},
#  {'Product type': 'haircare',
#   'SKU': 'SKU57',
#   'Price': 49.26320535073416,
#   'Availability': 65,
#   'Number of products sold': 227,
#   'Revenue generated': 1605.8669003924058,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 5,
#   'Lead times': 18,
#   'Order quantities': 51,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 9.16055853538187,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Delhi',
#   'Lead time': 21,
#   'Production volumes': 588,
#   'Manufacturing lead time': 25,
#   'Manufacturing costs': 67.77962298707814,
#   'Inspection results': 'Pending',
#   'Defect rates': 2.511174830212707,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 482.1912386025281},
#  {'Product type': 'skincare',
#   'SKU': 'SKU58',
#   'Price': 59.84156137728931,
#   'Availability': 81,
#   'Number of products sold': 896,
#   'Revenue generated': 2021.149810337108,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 10,
#   'Lead times': 5,
#   'Order quantities': 44,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 4.93843856471209,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Delhi',
#   'Lead time': 18,
#   'Production volumes': 396,
#   'Manufacturing lead time': 7,
#   'Manufacturing costs': 65.04741509469146,
#   'Inspection results': 'Fail',
#   'Defect rates': 1.7303747198591968,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 110.36433523136472},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU59',
#   'Price': 63.828398347710966,
#   'Availability': 30,
#   'Number of products sold': 484,
#   'Revenue generated': 1061.618523013288,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 100,
#   'Lead times': 16,
#   'Order quantities': 26,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 7.293722596867728,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Kolkata',
#   'Lead time': 11,
#   'Production volumes': 176,
#   'Manufacturing lead time': 4,
#   'Manufacturing costs': 1.900762243519458,
#   'Inspection results': 'Fail',
#   'Defect rates': 0.4471940154638232,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 312.5742736100933},
#  {'Product type': 'skincare',
#   'SKU': 'SKU60',
#   'Price': 17.028027920188702,
#   'Availability': 16,
#   'Number of products sold': 380,
#   'Revenue generated': 8864.084349586436,
#   'Customer demographics': 'Female',
#   'Stock levels': 41,
#   'Lead times': 27,
#   'Order quantities': 72,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 4.3813681581023145,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Mumbai',
#   'Lead time': 29,
#   'Production volumes': 929,
#   'Manufacturing lead time': 24,
#   'Manufacturing costs': 87.21305781513568,
#   'Inspection results': 'Fail',
#   'Defect rates': 2.853090616649054,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 430.1690969751365},
#  {'Product type': 'haircare',
#   'SKU': 'SKU61',
#   'Price': 52.02874990329492,
#   'Availability': 23,
#   'Number of products sold': 117,
#   'Revenue generated': 6885.589350896253,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 32,
#   'Lead times': 23,
#   'Order quantities': 36,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 9.030340422521949,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Kolkata',
#   'Lead time': 14,
#   'Production volumes': 480,
#   'Manufacturing lead time': 12,
#   'Manufacturing costs': 78.7023939688789,
#   'Inspection results': 'Fail',
#   'Defect rates': 4.367470538205053,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 164.36652824341942},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU62',
#   'Price': 72.79635395558736,
#   'Availability': 89,
#   'Number of products sold': 270,
#   'Revenue generated': 3899.746833729224,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 86,
#   'Lead times': 2,
#   'Order quantities': 40,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 7.291701388776776,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Mumbai',
#   'Lead time': 13,
#   'Production volumes': 751,
#   'Manufacturing lead time': 14,
#   'Manufacturing costs': 21.048642725168644,
#   'Inspection results': 'Pass',
#   'Defect rates': 1.8740014040443749,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route C',
#   'Costs': 320.8465157591116},
#  {'Product type': 'skincare',
#   'SKU': 'SKU63',
#   'Price': 13.017376785287857,
#   'Availability': 55,
#   'Number of products sold': 246,
#   'Revenue generated': 4256.949140850225,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 54,
#   'Lead times': 19,
#   'Order quantities': 10,
#   'Shipping times': 4,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 2.45793352798733,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Bangalore',
#   'Lead time': 18,
#   'Production volumes': 736,
#   'Manufacturing lead time': 10,
#   'Manufacturing costs': 20.075003975630484,
#   'Inspection results': 'Pending',
#   'Defect rates': 3.6328432903821337,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route A',
#   'Costs': 687.2861778664173},
#  {'Product type': 'skincare',
#   'SKU': 'SKU64',
#   'Price': 89.63409560813533,
#   'Availability': 11,
#   'Number of products sold': 134,
#   'Revenue generated': 8458.730878367178,
#   'Customer demographics': 'Female',
#   'Stock levels': 73,
#   'Lead times': 27,
#   'Order quantities': 75,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 4.585353468194652,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Delhi',
#   'Lead time': 17,
#   'Production volumes': 328,
#   'Manufacturing lead time': 6,
#   'Manufacturing costs': 8.693042425877287,
#   'Inspection results': 'Fail',
#   'Defect rates': 0.1594863147175146,
#   'Transportation modes': 'Air',
#   'Routes': 'Route C',
#   'Costs': 771.2250846811575},
#  {'Product type': 'skincare',
#   'SKU': 'SKU65',
#   'Price': 33.69771720664313,
#   'Availability': 72,
#   'Number of products sold': 457,
#   'Revenue generated': 8354.579686481995,
#   'Customer demographics': 'Male',
#   'Stock levels': 57,
#   'Lead times': 24,
#   'Order quantities': 54,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 6.580541347884595,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Kolkata',
#   'Lead time': 16,
#   'Production volumes': 358,
#   'Manufacturing lead time': 21,
#   'Manufacturing costs': 1.5972227430506774,
#   'Inspection results': 'Fail',
#   'Defect rates': 4.911095954842331,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route C',
#   'Costs': 555.8591036717435},
#  {'Product type': 'skincare',
#   'SKU': 'SKU66',
#   'Price': 26.03486977396209,
#   'Availability': 52,
#   'Number of products sold': 704,
#   'Revenue generated': 8367.721618020154,
#   'Customer demographics': 'Female',
#   'Stock levels': 13,
#   'Lead times': 17,
#   'Order quantities': 19,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 2.2161427287713638,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Kolkata',
#   'Lead time': 24,
# ...
#   'Defect rates': 3.055141818307548,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 852.56809891985},
#  {'Product type': 'haircare',
#   'SKU': 'SKU78',
#   'Price': 6.306883176111915,
#   'Availability': 50,
#   'Number of products sold': 946,
#   'Revenue generated': 1292.4584179377562,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 5,
#   'Lead times': 4,
#   'Order quantities': 51,
#   'Shipping times': 5,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 8.46704977086199,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Mumbai',
#   'Lead time': 25,
#   'Production volumes': 858,
#   'Manufacturing lead time': 21,
#   'Manufacturing costs': 71.12651472040338,
#   'Inspection results': 'Pending',
#   'Defect rates': 4.096881332470452,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route C',
#   'Costs': 323.59220343132216},
#  {'Product type': 'haircare',
#   'SKU': 'SKU79',
#   'Price': 57.05703122110322,
#   'Availability': 56,
#   'Number of products sold': 198,
#   'Revenue generated': 7888.723268427081,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 31,
#   'Lead times': 25,
#   'Order quantities': 20,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 6.4963253642950445,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Bangalore',
#   'Lead time': 5,
#   'Production volumes': 228,
#   'Manufacturing lead time': 12,
#   'Manufacturing costs': 57.87090292403628,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.1658716274806082,
#   'Transportation modes': 'Air',
#   'Routes': 'Route C',
#   'Costs': 351.50421933503867},
#  {'Product type': 'skincare',
#   'SKU': 'SKU80',
#   'Price': 91.12831835044432,
#   'Availability': 75,
#   'Number of products sold': 872,
#   'Revenue generated': 8651.672682982065,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 39,
#   'Lead times': 14,
#   'Order quantities': 41,
#   'Shipping times': 2,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 2.8331846794189746,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Chennai',
#   'Lead time': 8,
#   'Production volumes': 202,
#   'Manufacturing lead time': 5,
#   'Manufacturing costs': 76.96122802382001,
#   'Inspection results': 'Fail',
#   'Defect rates': 2.8496621985053308,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route B',
#   'Costs': 787.7798504943445},
#  {'Product type': 'haircare',
#   'SKU': 'SKU81',
#   'Price': 72.81920693031822,
#   'Availability': 9,
#   'Number of products sold': 774,
#   'Revenue generated': 4384.413400045863,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 48,
#   'Lead times': 6,
#   'Order quantities': 8,
#   'Shipping times': 5,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 4.066277501512044,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Delhi',
#   'Lead time': 28,
#   'Production volumes': 698,
#   'Manufacturing lead time': 1,
#   'Manufacturing costs': 19.789592941903603,
#   'Inspection results': 'Pending',
#   'Defect rates': 2.547547121548712,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 276.77833594679885},
#  {'Product type': 'skincare',
#   'SKU': 'SKU82',
#   'Price': 17.034930739467917,
#   'Availability': 13,
#   'Number of products sold': 336,
#   'Revenue generated': 2943.3818676094515,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 42,
#   'Lead times': 19,
#   'Order quantities': 72,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 4.70818187354193,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Mumbai',
#   'Lead time': 6,
#   'Production volumes': 955,
#   'Manufacturing lead time': 26,
#   'Manufacturing costs': 4.46527843494324,
#   'Inspection results': 'Pending',
#   'Defect rates': 4.137877048622357,
#   'Transportation modes': 'Road',
#   'Routes': 'Route C',
#   'Costs': 589.9785556280407},
#  {'Product type': 'haircare',
#   'SKU': 'SKU83',
#   'Price': 68.91124621160633,
#   'Availability': 82,
#   'Number of products sold': 663,
#   'Revenue generated': 2411.754632110491,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 65,
#   'Lead times': 24,
#   'Order quantities': 7,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 4.949839577996949,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Bangalore',
#   'Lead time': 20,
#   'Production volumes': 443,
#   'Manufacturing lead time': 5,
#   'Manufacturing costs': 97.73059380053304,
#   'Inspection results': 'Fail',
#   'Defect rates': 0.7730061340672478,
#   'Transportation modes': 'Road',
#   'Routes': 'Route A',
#   'Costs': 682.9710182260933},
#  {'Product type': 'haircare',
#   'SKU': 'SKU84',
#   'Price': 89.10436729210225,
#   'Availability': 99,
#   'Number of products sold': 618,
#   'Revenue generated': 2048.2900998487103,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 73,
#   'Lead times': 26,
#   'Order quantities': 80,
#   'Shipping times': 10,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 8.381615624922631,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Chennai',
#   'Lead time': 24,
#   'Production volumes': 589,
#   'Manufacturing lead time': 22,
#   'Manufacturing costs': 33.808636513209095,
#   'Inspection results': 'Pass',
#   'Defect rates': 4.843456577118041,
#   'Transportation modes': 'Air',
#   'Routes': 'Route B',
#   'Costs': 465.457005963688},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU85',
#   'Price': 76.96299441519388,
#   'Availability': 83,
#   'Number of products sold': 25,
#   'Revenue generated': 8684.613059253858,
#   'Customer demographics': 'Female',
#   'Stock levels': 15,
#   'Lead times': 18,
#   'Order quantities': 66,
#   'Shipping times': 2,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 8.249168704871728,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Chennai',
#   'Lead time': 4,
#   'Production volumes': 211,
#   'Manufacturing lead time': 2,
#   'Manufacturing costs': 69.9293455186723,
#   'Inspection results': 'Fail',
#   'Defect rates': 1.3744289997457582,
#   'Transportation modes': 'Road',
#   'Routes': 'Route B',
#   'Costs': 842.6868300046415},
#  {'Product type': 'skincare',
#   'SKU': 'SKU86',
#   'Price': 19.99817694040422,
#   'Availability': 18,
#   'Number of products sold': 223,
#   'Revenue generated': 1229.5910285649834,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 32,
#   'Lead times': 14,
#   'Order quantities': 22,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 1.4543053101535517,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Mumbai',
#   'Lead time': 4,
#   'Production volumes': 569,
#   'Manufacturing lead time': 18,
#   'Manufacturing costs': 74.60896999519468,
#   'Inspection results': 'Pass',
#   'Defect rates': 2.0515129307662465,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 264.2548898358665},
#  {'Product type': 'haircare',
#   'SKU': 'SKU87',
#   'Price': 80.41403665035574,
#   'Availability': 24,
#   'Number of products sold': 79,
#   'Revenue generated': 5133.846701086692,
#   'Customer demographics': 'Male',
#   'Stock levels': 5,
#   'Lead times': 7,
#   'Order quantities': 55,
#   'Shipping times': 10,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 6.575803797548535,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Chennai',
#   'Lead time': 27,
#   'Production volumes': 523,
#   'Manufacturing lead time': 17,
#   'Manufacturing costs': 28.69699682414317,
#   'Inspection results': 'Fail',
#   'Defect rates': 3.693737787839276,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route B',
#   'Costs': 879.3592177349243},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU88',
#   'Price': 75.27040697572501,
#   'Availability': 58,
#   'Number of products sold': 737,
#   'Revenue generated': 9444.74203306298,
#   'Customer demographics': 'Male',
#   'Stock levels': 60,
#   'Lead times': 18,
#   'Order quantities': 85,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 3.8012531329310777,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Mumbai',
#   'Lead time': 21,
#   'Production volumes': 953,
#   'Manufacturing lead time': 11,
#   'Manufacturing costs': 68.18491905704117,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.722204401882931,
#   'Transportation modes': 'Sea',
#   'Routes': 'Route A',
#   'Costs': 103.91624796070496},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU89',
#   'Price': 97.76008558193868,
#   'Availability': 10,
#   'Number of products sold': 134,
#   'Revenue generated': 5924.682566853231,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 90,
#   'Lead times': 1,
#   'Order quantities': 27,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 9.92981624527726,
#   'Supplier name': 'Supplier 1',
#   'Location': 'Kolkata',
#   'Lead time': 23,
#   'Production volumes': 370,
#   'Manufacturing lead time': 11,
#   'Manufacturing costs': 46.60387338164447,
#   'Inspection results': 'Pending',
#   'Defect rates': 1.9076657339590744,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 517.4999739290605},
#  {'Product type': 'skincare',
#   'SKU': 'SKU90',
#   'Price': 13.881913501359142,
#   'Availability': 56,
#   'Number of products sold': 320,
#   'Revenue generated': 9592.633570280312,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 66,
#   'Lead times': 18,
#   'Order quantities': 96,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 7.674430708112694,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Bangalore',
#   'Lead time': 8,
#   'Production volumes': 585,
#   'Manufacturing lead time': 8,
#   'Manufacturing costs': 85.67596333579797,
#   'Inspection results': 'Pass',
#   'Defect rates': 1.2193822244013883,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 990.0784725058112},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU91',
#   'Price': 62.11196546396179,
#   'Availability': 90,
#   'Number of products sold': 916,
#   'Revenue generated': 1935.206793507599,
#   'Customer demographics': 'Male',
#   'Stock levels': 98,
#   'Lead times': 22,
#   'Order quantities': 85,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 7.471514084401146,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Delhi',
#   'Lead time': 5,
#   'Production volumes': 207,
#   'Manufacturing lead time': 28,
#   'Manufacturing costs': 39.772882502339975,
#   'Inspection results': 'Pending',
#   'Defect rates': 0.6260018582093946,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 996.7783149506238},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU92',
#   'Price': 47.71423307582023,
#   'Availability': 44,
#   'Number of products sold': 276,
#   'Revenue generated': 2100.1297546259366,
#   'Customer demographics': 'Male',
#   'Stock levels': 90,
#   'Lead times': 25,
#   'Order quantities': 10,
#   'Shipping times': 8,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 4.469500026123601,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Mumbai',
#   'Lead time': 4,
#   'Production volumes': 671,
#   'Manufacturing lead time': 29,
#   'Manufacturing costs': 62.61269039561434,
#   'Inspection results': 'Pass',
#   'Defect rates': 0.3334318252247392,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 230.0927825367629},
#  {'Product type': 'haircare',
#   'SKU': 'SKU93',
#   'Price': 69.29083100290549,
#   'Availability': 88,
#   'Number of products sold': 114,
#   'Revenue generated': 4531.4021336919095,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 63,
#   'Lead times': 17,
#   'Order quantities': 66,
#   'Shipping times': 1,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 7.0064320590043945,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Chennai',
#   'Lead time': 21,
#   'Production volumes': 824,
#   'Manufacturing lead time': 20,
#   'Manufacturing costs': 35.63365234334388,
#   'Inspection results': 'Fail',
#   'Defect rates': 4.165781795424145,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 823.5238458881558},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU94',
#   'Price': 3.037688724631414,
#   'Availability': 97,
#   'Number of products sold': 987,
#   'Revenue generated': 7888.356546661873,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 77,
#   'Lead times': 26,
#   'Order quantities': 72,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 6.942945942032581,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Delhi',
#   'Lead time': 12,
#   'Production volumes': 908,
#   'Manufacturing lead time': 14,
#   'Manufacturing costs': 60.38737861486212,
#   'Inspection results': 'Pass',
#   'Defect rates': 1.4636074984727798,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 846.6652569866948},
#  {'Product type': 'haircare',
#   'SKU': 'SKU95',
#   'Price': 77.90392721944775,
#   'Availability': 65,
#   'Number of products sold': 672,
#   'Revenue generated': 7386.363944048664,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 15,
#   'Lead times': 14,
#   'Order quantities': 26,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 8.630338869602754,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Mumbai',
#   'Lead time': 18,
#   'Production volumes': 450,
#   'Manufacturing lead time': 26,
#   'Manufacturing costs': 58.89068576858998,
#   'Inspection results': 'Pending',
#   'Defect rates': 1.2108821295850665,
#   'Transportation modes': 'Air',
#   'Routes': 'Route A',
#   'Costs': 778.8642413766479},
#  {'Product type': 'cosmetics',
#   'SKU': 'SKU96',
#   'Price': 24.42313142037338,
#   'Availability': 29,
#   'Number of products sold': 324,
#   'Revenue generated': 7698.424765632117,
#   'Customer demographics': 'Non-binary',
#   'Stock levels': 67,
#   'Lead times': 2,
#   'Order quantities': 32,
#   'Shipping times': 3,
#   'Shipping carriers': 'Carrier C',
#   'Shipping costs': 5.352878043996809,
#   'Supplier name': 'Supplier 3',
#   'Location': 'Mumbai',
#   'Lead time': 28,
#   'Production volumes': 648,
#   'Manufacturing lead time': 28,
#   'Manufacturing costs': 17.80375633139127,
#   'Inspection results': 'Pending',
#   'Defect rates': 3.872047681482133,
#   'Transportation modes': 'Road',
#   'Routes': 'Route A',
#   'Costs': 188.74214114905695},
#  {'Product type': 'haircare',
#   'SKU': 'SKU97',
#   'Price': 3.526111259143416,
#   'Availability': 56,
#   'Number of products sold': 62,
#   'Revenue generated': 4370.916579984536,
#   'Customer demographics': 'Male',
#   'Stock levels': 46,
#   'Lead times': 19,
#   'Order quantities': 4,
#   'Shipping times': 9,
#   'Shipping carriers': 'Carrier A',
#   'Shipping costs': 7.904845611209675,
#   'Supplier name': 'Supplier 4',
#   'Location': 'Mumbai',
#   'Lead time': 10,
#   'Production volumes': 535,
#   'Manufacturing lead time': 13,
#   'Manufacturing costs': 65.76515592636746,
#   'Inspection results': 'Fail',
#   'Defect rates': 3.376237834717981,
#   'Transportation modes': 'Road',
#   'Routes': 'Route A',
#   'Costs': 540.1324228679678},
#  {'Product type': 'skincare',
#   'SKU': 'SKU98',
#   'Price': 19.7546048668786,
#   'Availability': 43,
#   'Number of products sold': 913,
#   'Revenue generated': 8525.952559683526,
#   'Customer demographics': 'Female',
#   'Stock levels': 53,
#   'Lead times': 1,
#   'Order quantities': 27,
#   'Shipping times': 7,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 1.409801095138073,
#   'Supplier name': 'Supplier 5',
#   'Location': 'Chennai',
#   'Lead time': 28,
#   'Production volumes': 581,
#   'Manufacturing lead time': 9,
#   'Manufacturing costs': 5.604690864371781,
#   'Inspection results': 'Pending',
#   'Defect rates': 2.908122169351261,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route A',
#   'Costs': 882.1988635470415},
#  {'Product type': 'haircare',
#   'SKU': 'SKU99',
#   'Price': 68.51783269927664,
#   'Availability': 17,
#   'Number of products sold': 627,
#   'Revenue generated': 9185.185829181704,
#   'Customer demographics': 'Unknown',
#   'Stock levels': 55,
#   'Lead times': 8,
#   'Order quantities': 59,
#   'Shipping times': 6,
#   'Shipping carriers': 'Carrier B',
#   'Shipping costs': 1.3110237561206226,
#   'Supplier name': 'Supplier 2',
#   'Location': 'Chennai',
#   'Lead time': 29,
#   'Production volumes': 921,
#   'Manufacturing lead time': 2,
#   'Manufacturing costs': 38.07289852062604,
#   'Inspection results': 'Fail',
#   'Defect rates': 0.3460272907055034,
#   'Transportation modes': 'Rail',
#   'Routes': 'Route B',
#   'Costs': 210.74300896424612}]
